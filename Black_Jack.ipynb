# %%
from random import shuffle
suits = ['Clubs','Diamonds','Hearts','Spades']
ranks = [ 'Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace']
values = {'Two':2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,'Queen':10,'King':10,'Ace':11}
class Card():
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value = values[rank] 

    
         

    def __str__(self):
        return self.rank + ' of ' + self.suit

class Deck:
    def __init__(self):
        self.all_cards = []
        for suit in suits:
            for rank in ranks:
                created_objects = Card(suit,rank)
                self.all_cards.append(created_objects)
    def remove_one(self):
        return self.all_cards.pop()
    def shuffle_cards(self):
        shuffle(self.all_cards)
    
class player_class():
    def __init__(self,name):
        self.store_cards = []
        self.name = name
        self.balance = 1000
    def betting_amount(self):
        bet_money = input('Enter the amount of money you want to bet (your current balance is 1000$ and max:200$ and min:100) : ')
        self.balance = self.balance - int(bet_money) 
        print('the current balance of {} is {}$ '.format(self.name,self.balance))
        return bet_money
    def recieve_money(self,betamount):
        self.balance = betamount + self.balance
        print(f'Your Current Balance :{self.balance}')
        
    def cards_total_value(self,player_table_card):
        player_total=0
        for x in player_table_card:
            player_total= player_total + (x.value)
        print(f'The total sum of {len(player_table_card)} cards of players are {player_total}')
        return player_total

    def player_ace(self,player_table_card):
        for x in player_table_card:
            if x.rank == 'Ace':
                print( 'we have found ace in your cards')
                print('NOTE : IF YOU HAVE 2 ACE THEN PLEASE ENTER THE FIRST CARD AS 11 AND SECOND CARD 1')
                print('--------------------------------OR-----------------------------------------------')
                print(' OR IF YOU HAVE ONLY ONE CARD JUST ENTER ITS VALUE AS 11')
                ace_value = input('Do you want to take value as 11 or 1 : ')
                x.value = int(ace_value)
                print('your cards value has changed')
                print(x.value)
            else:
                pass
                
    def player__single_ace(self,card):
        if card.rank == 'Ace':
            print('this is ace card')
            ace_value = input('Do you want to take value as 11 or 1 : ')
            card.value = int(ace_value)
            print('your card value has changed')
            print(card.value)
        else:
            pass
        
player_athish.cards_total_value(player_table_card)  
        
        
        

class dealer_class():
    def __init__(self):
        self.storing_cards = []
        self.amount= 10000000
    def give_cards(self):
        card = self.storing_cards.pop(-1)
        return card
    def add_cards(self,new_cards):
        self.storing_cards.append(new_cards)

    def recieve_amount(self,amount):
        self.amount = amount + self.amount
        print(f' Dealers Current Balance :{self.amount}')
        
    def cards_total_value(self,dealer_table_card):
        dealer_total = 0   
        for x in dealer_table_card:
            dealer_total= dealer_total + (x.value)
        print(f'The total sum of {len(dealer_table_card)} cards of dealers are {dealer_total}')
        return dealer_total
        
    def dealers_money_giving(self,amount):
        self.amount = self.amount-amount
        return self.amount
    
    def dealers_final_value(self,dealer_total_value):
        dealers_final_value=dealer_total_value
        return f'dealers_final_value: {dealers_final_value}'
        
    def replay(self):
        choice = input('want to play again, enter yes or no : ')
        return choice

    def Ask_HIT(self):
            Ask_HIT = input('please enter (HIT), if you want a HIT : ')
            return Ask_HIT

dealer = dealer_class()
